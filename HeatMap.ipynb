# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import pandas as pd

# %%
var = pd.read_csv(r"C:\Users\smrut\Downloads\attention.csv")
var
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...

# %%
data = var.drop(columns=["attention"],axis = 1).head(10)
data
# Out:
#    Unnamed: 0  subject  solutions  score
# 0           0        1          1    2.0
# 1           1        2          1    3.0
# 2           2        3          1    3.0
# 3           3        4          1    5.0
# 4           4        5          1    4.0
# 5           5        6          1    5.0
# 6           6        7          1    5.0
# 7           7        8          1    5.0
# 8           8        9          1    2.0
# 9           9       10          1    6.0

# %%
sns.heatmap(data,vmin = 0,vmax = 15,cmap="gist_heat",annot = True)
plt.show()

# %%
num = np.linspace(1,10,12).reshape(3,4)
num
# Out:
# array([[ 1.        ,  1.81818182,  2.63636364,  3.45454545],
#        [ 4.27272727,  5.09090909,  5.90909091,  6.72727273],
#        [ 7.54545455,  8.36363636,  9.18181818, 10.        ]])

# %%
sns.heatmap(num,vmin = 0,vmax = 15,cmap="PuOr",annot = True)
plt.show()

# %%
arr = np.array([["a0","a1","a2","a3"],
               ["b0","b1","b2","b3"],
               ["c0","c1","c2","c3"]])
arr
# Out:
# array([['a0', 'a1', 'a2', 'a3'],
#        ['b0', 'b1', 'b2', 'b3'],
#        ['c0', 'c1', 'c2', 'c3']], dtype='<U2')

# %%
y = {"fontsize":10,"color":"b"}
x = sns.heatmap(num,vmin = 0,vmax = 15,cmap="PuOr",annot = arr,fmt="s",annot_kws=y,linewidth = 4, linecolor = "b",cbar = False,xticklabels = False,)
x.set(xlabel = "Smruti", ylabel = "Data")
sns.set(font_scale = 1)
plt.show()
